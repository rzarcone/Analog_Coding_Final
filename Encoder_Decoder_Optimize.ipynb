# %% [markdown]
# Notebook to calculate the optimal encoder and decoder for pcm channels -- Ryan Zarcone

# %%
# %env CUDA_VISIBLE_DEVICES=1
# %matplotlib inline
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
import numpy as np
import tensorflow as tf
from get_data import get_memristor_data
try: 
    from itertools import izip
except:
    izip = zip
    
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
    
import os
if not os.path.exists('model_params/'):
    os.makedirs('model_params/')
    
import pandas as pd
import scipy
from scipy import optimize, interpolate, stats
from pylab import *

# %%
def gauss_interp(mem, samp, xs, ys, interp_width, ratio=0.75):
    """
    Parameters
    ----------
    samp : tf.tensor (batch_size, n_m)
    xs : tf.tensor (n_p, n_m)
        Grid inputs
    ys : tf.tensor (n_p, n_m)
        Grid outputs
    interp_width : float
        Spacing between the xs
    Returns
    -------
    interp_func : tf.tensor (batch_size, n_m)
    """
    samp = tf.expand_dims(samp, 1)  # (batch, 1, n_m)
    xs = tf.cast(tf.expand_dims(xs, 0), tf.float32)  # (1, n_p, n_m)
    ys = tf.cast(tf.expand_dims(ys, 0), tf.float32)  # (1, n_p, n_m)
    sig = np.float32(ratio * interp_width)  # spacing of xs
    norm_factor = np.sqrt(2 * np.pi) * sig / interp_width
    norm_factor = np.array(norm_factor, dtype='float32')
    
    if mem: 
        output = tf.reduce_sum(ys * tf.exp( -0.5 * (samp - xs) ** 2 / sig ** 2) /
                         norm_factor,
                  reduction_indices=1)
    else:
        output = tf.reduce_sum(tf.spectral.dct(ys * tf.exp( -0.5 * (samp - xs) ** 2 / sig ** 2) /
                         norm_factor),
                  reduction_indices=1)
    return output

# %%
def memristor_output(v, eps, vs, mus, sigs, interp_width):
    """
    Parameters
    ----------
    mu, sig, eps : tf.tensor (batch_size, n_m)
        mean, standard deviation, noise
    """
    mean = gauss_interp(True, v, vs, mus, interp_width)
    sdev = gauss_interp(True, v, vs, sigs, interp_width)
    return mean + eps * sdev

# %%
def _train_graph(
    graph,
    init_op,
    train_op,
    cost_op, 
    summary_dict,
    saver,
    train_data_object,
    summary_data_object,
    feed_vars,
    batch_size,
    num_epochs,
    param_file,
    checkpoint_every_n_epochs,
    global_step,
    save_path='tmp/model.ckpt'
):
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True

    inc_global_step = tf.assign(global_step, global_step + 1)
    with tf.Session(graph=graph, config=config) as sess:
        sess.run(init_op) if param_file is None else saver.restore(sess, param_file)
        for j in range(num_epochs):
            sess.run(inc_global_step)
            train_data_generator = train_data_object.get_generator(batch_size)
            for feed_values in train_data_generator:
                sess.run(
                    train_op,
                    feed_dict=dict(zip(feed_vars, feed_values))
                )

            summary_data_generator = summary_data_object.get_generator()
            for feed_values in summary_data_generator:
                summary_vals = sess.run(summary_dict,
                    feed_dict=dict(zip(feed_vars, feed_values))
                )
                print(
                    'Iteration: {}  '.format(j) +
                    ''.join(['{}: {:0.6f} '.format(k, v) for k, v in
                         summary_vals.items()]))
            if j % checkpoint_every_n_epochs == 0:
                new_save_path = saver.save(
                    sess, save_path, global_step=j)

        new_save_path = saver.save(sess, save_path)
    return new_save_path

# %%
def _eval_graph(
    graph,
    saver,
    eval_ops,
    data_object,
    feed_vars,
    param_file):

    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True

    with tf.Session(graph=graph, config=config) as sess:
        saver.restore(sess, param_file)
        data_generator = data_object.get_generator()
        for feed_values in data_generator:
            eval_vals = sess.run(eval_ops,
                feed_dict=dict(zip(feed_vars, feed_values))
            )
    return eval_vals

# %%
def random_generator(batch_size, n_features, max_size=10):
    for i in range(max_size):
        yield np.random.randn(batch_size, n_features)

class DataAndNoiseGenerator(object):
    """
    Object that Handles Creation of Data Generators.
    """
    def __init__(self, data_dim, noise_dim, max_size=1):
        self.data_dim = data_dim
        self.noise_dim = noise_dim
        self.max_size = max_size

    def get_generator(self, batch_size=None):
        if batch_size is None:
            batch_size = self.data_dim[0]
        max_size = self.max_size
        input_gen = random_generator(*self.data_dim, max_size=max_size)
        rand_gen = random_generator(*self.noise_dim, max_size=max_size)
        return izip(input_gen, rand_gen)

# %%
n_m = 1
old_batch_size = 10000
batch_size = 10000 #used to be 10000
mem_path = 'Data/PCM_20140605.pkl'
pcm_device = 'new'
old_lr = 0.0005
lr = 0.0005 #was 0.0005
num_epochs=301 
ratio = 0.75
num_linspace = 300
norm_min = -2.0 # added Rs = normalizer(Rs,norm_min-2.0,norm_max) to get_memristor_data to make go down to -3.   
norm_max = 2.0 
old_reg_loss_coef = 2.5
reg_loss_coef = 2.5
smoothness_coef = 1.0
optimizer = 'adam'

# %%
param_string = (pcm_device+'_'+str(batch_size)+'_'+str(lr)+'_'
                +str(num_epochs)+'_'+str(ratio)
                +'_'+str(num_linspace)+'_'+str(norm_min)
                +'_'+str(norm_max)+'_'+str(reg_loss_coef)
                +'_'+str(smoothness_coef)
                +'_'+optimizer)

# %%
old_param_string = (pcm_device+'_'+str(old_batch_size)+'_'+str(old_lr)+'_'
                +str(num_epochs)+'_'+str(ratio)
                +'_'+str(num_linspace)+'_'+str(norm_min)
                +'_'+str(norm_max)+'_'+str(old_reg_loss_coef)
                +'_'+str(smoothness_coef)
                +'_'+optimizer)

# %%
vs_data, mus_data, sigs_data, orig_vmin, orig_vmax, orig_rmin, orig_rmax = get_memristor_data(pcm_device = pcm_device, path=mem_path, 
                                                              n_mem=n_m, norm_min=norm_min, 
                                                              norm_max = norm_max)

# %%
plt.plot(vs_data, mus_data+sigs_data, c='red')
plt.plot(vs_data, mus_data)
plt.plot(vs_data, mus_data-sigs_data, c='red')

# %%
def smoother(y):
    return tf.reduce_mean((y[2:] + y[:-2] - 2 * y[1:-1]) ** 2) * smoothness_coef

# %%
g = tf.Graph()
with g.as_default():
    tp = tf.placeholder(dtype='float32', shape=(batch_size, n_m))
    # Encoder
    xx = np.linspace(-3.0, 3.0, num_linspace)[:, np.newaxis].astype('float32') 
    x_encoder = tf.Variable(initial_value=xx, trainable=False)
    y_encoder = tf.Variable(initial_value=xx, trainable=True)

    reg_encoder_loss = smoother(y_encoder)
    
    interp_width=(xx[1] - xx[0])
    t = gauss_interp(True, tp, xs=x_encoder, ys=y_encoder, interp_width=interp_width, ratio=ratio)

    reg_loss = tf.reduce_mean(tf.reduce_sum(
                      reg_loss_coef * (tf.nn.relu(t - norm_max)
                      + tf.nn.relu(norm_min - t))))

    
    # Channel

    eps = tf.placeholder(dtype='float32', shape=(batch_size, n_m))
    vs, mus, sigs = [tf.Variable(initial_value=_, trainable=False) for _ in [vs_data, mus_data, sigs_data]]

    s = memristor_output(t, eps=eps, vs=vs, mus=mus, sigs=sigs, interp_width=vs_data[1] - vs_data[0])

    # Decoder
    x_decoder = tf.Variable(initial_value=xx, trainable=False)
    y_decoder = tf.Variable(initial_value=xx, trainable=True)

    reg_decoder_loss = smoother(y_decoder)
    sp = gauss_interp(True, s, xs=x_decoder, ys=y_decoder, interp_width=interp_width, ratio=ratio)

    
    rec_loss = tf.reduce_mean((sp - tp) ** 2)
    loss = rec_loss + reg_loss + reg_decoder_loss + reg_encoder_loss

    
    global_step = tf.Variable(0, name='global_step', trainable=False, dtype=tf.int32)
    

    opt = tf.train.AdamOptimizer(lr)

    
    train_op = opt.minimize(loss=loss, global_step=global_step)
    summary_dict={'loss': loss, 'reg_dec': reg_decoder_loss, 'reg_enc': reg_encoder_loss, 'reg_loss': reg_loss}
    
    feed_vars=[tp, eps]
    
    saver = tf.train.Saver()
    init_op = tf.global_variables_initializer()

# %%
data_gen_train = DataAndNoiseGenerator(data_dim=(batch_size, n_m), noise_dim=(batch_size, n_m), max_size=100)
data_gen_val = DataAndNoiseGenerator(data_dim=(batch_size, n_m), noise_dim=(batch_size, n_m))

# %%
_train_graph(
    graph=g,
    init_op=init_op,
    train_op=train_op,
    cost_op=None, 
    summary_dict=summary_dict,
    saver=saver,
    train_data_object=data_gen_train,
    summary_data_object=data_gen_val,
    feed_vars=feed_vars,
    batch_size=batch_size,
    num_epochs=num_epochs,
    param_file= 'model_params/' + old_param_string + '.ckpt-270', #switched from None to use step 290 of old run 
    checkpoint_every_n_epochs=10,
    global_step=global_step, save_path='model_params/' + param_string + '.ckpt'
)
# Out:
# INFO:tensorflow:Restoring parameters from model_params/new_10000_0.0005_301_0.75_300_-2.0_2.0_2.5_1.0_adam.ckpt-270
# Iteration: 0  reg_dec: 0.000148 loss: 0.125172 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 1  reg_dec: 0.000146 loss: 0.120169 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 2  reg_dec: 0.000150 loss: 0.126535 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 3  reg_dec: 0.000148 loss: 0.117523 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 4  reg_dec: 0.000150 loss: 0.110128 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 5  reg_dec: 0.000149 loss: 0.128938 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 6  reg_dec: 0.000150 loss: 0.131938 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 7  reg_dec: 0.000148 loss: 0.131762 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 8  reg_dec: 0.000147 loss: 0.116434 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 9  reg_dec: 0.000150 loss: 0.140931 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 10  reg_dec: 0.000150 loss: 0.125104 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 11  reg_dec: 0.000145 loss: 0.119488 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 12  reg_dec: 0.000145 loss: 0.120854 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 13  reg_dec: 0.000148 loss: 0.123867 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 14  reg_dec: 0.000149 loss: 0.140356 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 15  reg_dec: 0.000151 loss: 0.112040 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 16  reg_dec: 0.000149 loss: 0.127900 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 17  reg_dec: 0.000150 loss: 0.121596 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 18  reg_dec: 0.000147 loss: 0.109049 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 19  reg_dec: 0.000150 loss: 0.116737 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 20  reg_dec: 0.000146 loss: 0.109462 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 21  reg_dec: 0.000150 loss: 0.115945 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 22  reg_dec: 0.000152 loss: 0.114474 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 23  reg_dec: 0.000147 loss: 0.125123 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 24  reg_dec: 0.000149 loss: 0.121380 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 25  reg_dec: 0.000149 loss: 0.123018 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 26  reg_dec: 0.000149 loss: 0.130312 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 27  reg_dec: 0.000145 loss: 0.122368 reg_enc: 0.000589 reg_loss: 0.000010
# Iteration: 28  reg_dec: 0.000147 loss: 0.122624 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 29  reg_dec: 0.000147 loss: 0.127872 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 30  reg_dec: 0.000145 loss: 0.132994 reg_enc: 0.000599 reg_loss: 0.000000
# Iteration: 31  reg_dec: 0.000148 loss: 0.124321 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 32  reg_dec: 0.000148 loss: 0.112787 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 33  reg_dec: 0.000147 loss: 0.124780 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 34  reg_dec: 0.000148 loss: 0.117766 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 35  reg_dec: 0.000147 loss: 0.133953 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 36  reg_dec: 0.000148 loss: 0.121809 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 37  reg_dec: 0.000147 loss: 0.122663 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 38  reg_dec: 0.000146 loss: 0.130304 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 39  reg_dec: 0.000150 loss: 0.120487 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 40  reg_dec: 0.000149 loss: 0.117999 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 41  reg_dec: 0.000147 loss: 0.123700 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 42  reg_dec: 0.000150 loss: 0.126578 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 43  reg_dec: 0.000146 loss: 0.122545 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 44  reg_dec: 0.000149 loss: 0.121818 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 45  reg_dec: 0.000147 loss: 0.115815 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 46  reg_dec: 0.000144 loss: 0.128602 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 47  reg_dec: 0.000145 loss: 0.121967 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 48  reg_dec: 0.000144 loss: 0.117480 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 49  reg_dec: 0.000144 loss: 0.124436 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 50  reg_dec: 0.000144 loss: 0.127936 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 51  reg_dec: 0.000146 loss: 0.116360 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 52  reg_dec: 0.000147 loss: 0.127856 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 53  reg_dec: 0.000148 loss: 0.120902 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 54  reg_dec: 0.000150 loss: 0.126461 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 55  reg_dec: 0.000152 loss: 0.122463 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 56  reg_dec: 0.000150 loss: 0.133179 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 57  reg_dec: 0.000146 loss: 0.127145 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 58  reg_dec: 0.000150 loss: 0.119462 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 59  reg_dec: 0.000149 loss: 0.111853 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 60  reg_dec: 0.000147 loss: 0.103259 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 61  reg_dec: 0.000147 loss: 0.134889 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 62  reg_dec: 0.000144 loss: 0.126391 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 63  reg_dec: 0.000145 loss: 0.117864 reg_enc: 0.000599 reg_loss: 0.000000
# Iteration: 64  reg_dec: 0.000143 loss: 0.120685 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 65  reg_dec: 0.000148 loss: 0.113184 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 66  reg_dec: 0.000148 loss: 0.113297 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 67  reg_dec: 0.000149 loss: 0.122264 reg_enc: 0.000582 reg_loss: 0.000055
# Iteration: 68  reg_dec: 0.000148 loss: 0.134891 reg_enc: 0.000580 reg_loss: 0.000000
# Iteration: 69  reg_dec: 0.000146 loss: 0.130574 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 70  reg_dec: 0.000148 loss: 0.117418 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 71  reg_dec: 0.000146 loss: 0.141584 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 72  reg_dec: 0.000148 loss: 0.133895 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 73  reg_dec: 0.000148 loss: 0.122970 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 74  reg_dec: 0.000147 loss: 0.121514 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 75  reg_dec: 0.000147 loss: 0.111341 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 76  reg_dec: 0.000149 loss: 0.117724 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 77  reg_dec: 0.000147 loss: 0.116821 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 78  reg_dec: 0.000145 loss: 0.120141 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 79  reg_dec: 0.000145 loss: 0.135119 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 80  reg_dec: 0.000146 loss: 0.109394 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 81  reg_dec: 0.000146 loss: 0.106494 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 82  reg_dec: 0.000146 loss: 0.120034 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 83  reg_dec: 0.000146 loss: 0.129052 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 84  reg_dec: 0.000146 loss: 0.135150 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 85  reg_dec: 0.000151 loss: 0.127543 reg_enc: 0.000607 reg_loss: 0.000000
# Iteration: 86  reg_dec: 0.000152 loss: 0.129942 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 87  reg_dec: 0.000145 loss: 0.120347 reg_enc: 0.000603 reg_loss: 0.000000
# Iteration: 88  reg_dec: 0.000146 loss: 0.124849 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 89  reg_dec: 0.000147 loss: 0.117275 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 90  reg_dec: 0.000149 loss: 0.122920 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 91  reg_dec: 0.000146 loss: 0.120143 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 92  reg_dec: 0.000148 loss: 0.114590 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 93  reg_dec: 0.000146 loss: 0.114473 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 94  reg_dec: 0.000152 loss: 0.112057 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 95  reg_dec: 0.000148 loss: 0.110408 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 96  reg_dec: 0.000147 loss: 0.110347 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 97  reg_dec: 0.000144 loss: 0.111020 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 98  reg_dec: 0.000144 loss: 0.121845 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 99  reg_dec: 0.000148 loss: 0.101403 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 100  reg_dec: 0.000146 loss: 0.125212 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 101  reg_dec: 0.000146 loss: 0.121685 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 102  reg_dec: 0.000145 loss: 0.125332 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 103  reg_dec: 0.000147 loss: 0.134569 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 104  reg_dec: 0.000149 loss: 0.122826 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 105  reg_dec: 0.000147 loss: 0.129712 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 106  reg_dec: 0.000150 loss: 0.119397 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 107  reg_dec: 0.000147 loss: 0.114283 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 108  reg_dec: 0.000147 loss: 0.123446 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 109  reg_dec: 0.000148 loss: 0.107781 reg_enc: 0.000579 reg_loss: 0.000000
# Iteration: 110  reg_dec: 0.000148 loss: 0.127120 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 111  reg_dec: 0.000147 loss: 0.108182 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 112  reg_dec: 0.000147 loss: 0.125987 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 113  reg_dec: 0.000147 loss: 0.146868 reg_enc: 0.000609 reg_loss: 0.000000
# Iteration: 114  reg_dec: 0.000145 loss: 0.128052 reg_enc: 0.000604 reg_loss: 0.000000
# Iteration: 115  reg_dec: 0.000146 loss: 0.130531 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 116  reg_dec: 0.000144 loss: 0.130126 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 117  reg_dec: 0.000143 loss: 0.121967 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 118  reg_dec: 0.000144 loss: 0.115336 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 119  reg_dec: 0.000148 loss: 0.139178 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 120  reg_dec: 0.000144 loss: 0.142078 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 121  reg_dec: 0.000149 loss: 0.130041 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 122  reg_dec: 0.000146 loss: 0.129183 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 123  reg_dec: 0.000149 loss: 0.121122 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 124  reg_dec: 0.000148 loss: 0.112490 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 125  reg_dec: 0.000149 loss: 0.125122 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 126  reg_dec: 0.000149 loss: 0.121467 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 127  reg_dec: 0.000146 loss: 0.123055 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 128  reg_dec: 0.000149 loss: 0.118581 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 129  reg_dec: 0.000149 loss: 0.133795 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 130  reg_dec: 0.000148 loss: 0.122128 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 131  reg_dec: 0.000145 loss: 0.118723 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 132  reg_dec: 0.000147 loss: 0.131578 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 133  reg_dec: 0.000149 loss: 0.120352 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 134  reg_dec: 0.000147 loss: 0.119653 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 135  reg_dec: 0.000144 loss: 0.141631 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 136  reg_dec: 0.000144 loss: 0.124535 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 137  reg_dec: 0.000145 loss: 0.121217 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 138  reg_dec: 0.000146 loss: 0.133845 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 139  reg_dec: 0.000149 loss: 0.110572 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 140  reg_dec: 0.000150 loss: 0.112384 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 141  reg_dec: 0.000146 loss: 0.118332 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 142  reg_dec: 0.000149 loss: 0.126871 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 143  reg_dec: 0.000145 loss: 0.111092 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 144  reg_dec: 0.000149 loss: 0.132809 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 145  reg_dec: 0.000147 loss: 0.107288 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 146  reg_dec: 0.000146 loss: 0.128465 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 147  reg_dec: 0.000147 loss: 0.130682 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 148  reg_dec: 0.000147 loss: 0.123551 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 149  reg_dec: 0.000149 loss: 0.124800 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 150  reg_dec: 0.000151 loss: 0.122063 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 151  reg_dec: 0.000150 loss: 0.124345 reg_enc: 0.000606 reg_loss: 0.000000
# Iteration: 152  reg_dec: 0.000148 loss: 0.114476 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 153  reg_dec: 0.000145 loss: 0.134343 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 154  reg_dec: 0.000143 loss: 0.129590 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 155  reg_dec: 0.000146 loss: 0.119965 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 156  reg_dec: 0.000145 loss: 0.121609 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 157  reg_dec: 0.000143 loss: 0.114863 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 158  reg_dec: 0.000144 loss: 0.120871 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 159  reg_dec: 0.000145 loss: 0.118432 reg_enc: 0.000605 reg_loss: 0.000000
# Iteration: 160  reg_dec: 0.000145 loss: 0.115215 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 161  reg_dec: 0.000143 loss: 0.125309 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 162  reg_dec: 0.000146 loss: 0.118870 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 163  reg_dec: 0.000146 loss: 0.122987 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 164  reg_dec: 0.000144 loss: 0.119919 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 165  reg_dec: 0.000146 loss: 0.125216 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 166  reg_dec: 0.000143 loss: 0.124991 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 167  reg_dec: 0.000144 loss: 0.120814 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 168  reg_dec: 0.000151 loss: 0.129252 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 169  reg_dec: 0.000146 loss: 0.109934 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 170  reg_dec: 0.000147 loss: 0.123925 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 171  reg_dec: 0.000147 loss: 0.134393 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 172  reg_dec: 0.000147 loss: 0.120463 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 173  reg_dec: 0.000143 loss: 0.125298 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 174  reg_dec: 0.000148 loss: 0.134195 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 175  reg_dec: 0.000150 loss: 0.128872 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 176  reg_dec: 0.000149 loss: 0.126798 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 177  reg_dec: 0.000147 loss: 0.135543 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 178  reg_dec: 0.000145 loss: 0.118641 reg_enc: 0.000576 reg_loss: 0.000000
# Iteration: 179  reg_dec: 0.000150 loss: 0.137647 reg_enc: 0.000578 reg_loss: 0.000000
# Iteration: 180  reg_dec: 0.000147 loss: 0.117713 reg_enc: 0.000580 reg_loss: 0.000000
# Iteration: 181  reg_dec: 0.000147 loss: 0.119364 reg_enc: 0.000577 reg_loss: 0.000000
# Iteration: 182  reg_dec: 0.000147 loss: 0.126885 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 183  reg_dec: 0.000147 loss: 0.115676 reg_enc: 0.000580 reg_loss: 0.000000
# Iteration: 184  reg_dec: 0.000150 loss: 0.124814 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 185  reg_dec: 0.000150 loss: 0.122241 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 186  reg_dec: 0.000152 loss: 0.124178 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 187  reg_dec: 0.000148 loss: 0.112854 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 188  reg_dec: 0.000151 loss: 0.133613 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 189  reg_dec: 0.000148 loss: 0.127548 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 190  reg_dec: 0.000147 loss: 0.118050 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 191  reg_dec: 0.000146 loss: 0.120444 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 192  reg_dec: 0.000148 loss: 0.121839 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 193  reg_dec: 0.000147 loss: 0.119356 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 194  reg_dec: 0.000146 loss: 0.127894 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 195  reg_dec: 0.000146 loss: 0.121683 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 196  reg_dec: 0.000140 loss: 0.131525 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 197  reg_dec: 0.000146 loss: 0.133528 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 198  reg_dec: 0.000149 loss: 0.112169 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 199  reg_dec: 0.000148 loss: 0.125491 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 200  reg_dec: 0.000148 loss: 0.121625 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 201  reg_dec: 0.000151 loss: 0.119393 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 202  reg_dec: 0.000146 loss: 0.131896 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 203  reg_dec: 0.000146 loss: 0.137181 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 204  reg_dec: 0.000144 loss: 0.142668 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 205  reg_dec: 0.000144 loss: 0.115328 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 206  reg_dec: 0.000144 loss: 0.104740 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 207  reg_dec: 0.000149 loss: 0.126737 reg_enc: 0.000599 reg_loss: 0.000000
# Iteration: 208  reg_dec: 0.000145 loss: 0.133993 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 209  reg_dec: 0.000144 loss: 0.111986 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 210  reg_dec: 0.000144 loss: 0.119123 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 211  reg_dec: 0.000145 loss: 0.111022 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 212  reg_dec: 0.000148 loss: 0.135152 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 213  reg_dec: 0.000150 loss: 0.127687 reg_enc: 0.000599 reg_loss: 0.000042
# Iteration: 214  reg_dec: 0.000147 loss: 0.114618 reg_enc: 0.000607 reg_loss: 0.000000
# Iteration: 215  reg_dec: 0.000147 loss: 0.119544 reg_enc: 0.000602 reg_loss: 0.000000
# Iteration: 216  reg_dec: 0.000143 loss: 0.123798 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 217  reg_dec: 0.000145 loss: 0.114618 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 218  reg_dec: 0.000143 loss: 0.130900 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 219  reg_dec: 0.000144 loss: 0.126256 reg_enc: 0.000580 reg_loss: 0.000000
# Iteration: 220  reg_dec: 0.000144 loss: 0.135848 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 221  reg_dec: 0.000147 loss: 0.110977 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 222  reg_dec: 0.000146 loss: 0.118850 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 223  reg_dec: 0.000146 loss: 0.117910 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 224  reg_dec: 0.000144 loss: 0.120027 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 225  reg_dec: 0.000148 loss: 0.110208 reg_enc: 0.000589 reg_loss: 0.000000
# Iteration: 226  reg_dec: 0.000144 loss: 0.129064 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 227  reg_dec: 0.000145 loss: 0.115769 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 228  reg_dec: 0.000145 loss: 0.112067 reg_enc: 0.000579 reg_loss: 0.000000
# Iteration: 229  reg_dec: 0.000149 loss: 0.123639 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 230  reg_dec: 0.000145 loss: 0.122012 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 231  reg_dec: 0.000143 loss: 0.121315 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 232  reg_dec: 0.000142 loss: 0.125182 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 233  reg_dec: 0.000145 loss: 0.115904 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 234  reg_dec: 0.000144 loss: 0.116979 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 235  reg_dec: 0.000144 loss: 0.117846 reg_enc: 0.000581 reg_loss: 0.000000
# Iteration: 236  reg_dec: 0.000143 loss: 0.112854 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 237  reg_dec: 0.000143 loss: 0.115240 reg_enc: 0.000570 reg_loss: 0.000000
# Iteration: 238  reg_dec: 0.000143 loss: 0.123087 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 239  reg_dec: 0.000143 loss: 0.132124 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 240  reg_dec: 0.000145 loss: 0.097901 reg_enc: 0.000579 reg_loss: 0.000000
# Iteration: 241  reg_dec: 0.000146 loss: 0.133839 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 242  reg_dec: 0.000149 loss: 0.128639 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 243  reg_dec: 0.000145 loss: 0.126997 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 244  reg_dec: 0.000145 loss: 0.115985 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 245  reg_dec: 0.000144 loss: 0.120914 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 246  reg_dec: 0.000142 loss: 0.137227 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 247  reg_dec: 0.000144 loss: 0.111670 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 248  reg_dec: 0.000148 loss: 0.132866 reg_enc: 0.000610 reg_loss: 0.000017
# Iteration: 249  reg_dec: 0.000146 loss: 0.107375 reg_enc: 0.000606 reg_loss: 0.000000
# Iteration: 250  reg_dec: 0.000144 loss: 0.137930 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 251  reg_dec: 0.000147 loss: 0.109804 reg_enc: 0.000591 reg_loss: 0.000000
# Iteration: 252  reg_dec: 0.000151 loss: 0.129544 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 253  reg_dec: 0.000146 loss: 0.135861 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 254  reg_dec: 0.000146 loss: 0.132188 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 255  reg_dec: 0.000145 loss: 0.125571 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 256  reg_dec: 0.000145 loss: 0.125135 reg_enc: 0.000599 reg_loss: 0.000000
# Iteration: 257  reg_dec: 0.000145 loss: 0.116555 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 258  reg_dec: 0.000144 loss: 0.110443 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 259  reg_dec: 0.000142 loss: 0.112142 reg_enc: 0.000585 reg_loss: 0.000000
# Iteration: 260  reg_dec: 0.000147 loss: 0.116007 reg_enc: 0.000600 reg_loss: 0.000000
# Iteration: 261  reg_dec: 0.000145 loss: 0.136673 reg_enc: 0.000605 reg_loss: 0.000000
# Iteration: 262  reg_dec: 0.000146 loss: 0.137719 reg_enc: 0.000597 reg_loss: 0.000000
# Iteration: 263  reg_dec: 0.000144 loss: 0.121370 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 264  reg_dec: 0.000144 loss: 0.125806 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 265  reg_dec: 0.000143 loss: 0.116715 reg_enc: 0.000582 reg_loss: 0.000000
# Iteration: 266  reg_dec: 0.000144 loss: 0.115358 reg_enc: 0.000586 reg_loss: 0.000000
# Iteration: 267  reg_dec: 0.000145 loss: 0.123797 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 268  reg_dec: 0.000144 loss: 0.119190 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 269  reg_dec: 0.000142 loss: 0.117221 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 270  reg_dec: 0.000145 loss: 0.114587 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 271  reg_dec: 0.000143 loss: 0.113156 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 272  reg_dec: 0.000145 loss: 0.132981 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 273  reg_dec: 0.000140 loss: 0.137469 reg_enc: 0.000588 reg_loss: 0.000000
# Iteration: 274  reg_dec: 0.000144 loss: 0.128909 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 275  reg_dec: 0.000147 loss: 0.138350 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 276  reg_dec: 0.000143 loss: 0.116626 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 277  reg_dec: 0.000143 loss: 0.115322 reg_enc: 0.000604 reg_loss: 0.000000
# Iteration: 278  reg_dec: 0.000142 loss: 0.118489 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 279  reg_dec: 0.000147 loss: 0.123998 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 280  reg_dec: 0.000143 loss: 0.127384 reg_enc: 0.000587 reg_loss: 0.000000
# Iteration: 281  reg_dec: 0.000147 loss: 0.131182 reg_enc: 0.000584 reg_loss: 0.000000
# Iteration: 282  reg_dec: 0.000145 loss: 0.124154 reg_enc: 0.000583 reg_loss: 0.000000
# Iteration: 283  reg_dec: 0.000145 loss: 0.117317 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 284  reg_dec: 0.000143 loss: 0.118586 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 285  reg_dec: 0.000147 loss: 0.125561 reg_enc: 0.000593 reg_loss: 0.000000
# Iteration: 286  reg_dec: 0.000147 loss: 0.119585 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 287  reg_dec: 0.000146 loss: 0.118833 reg_enc: 0.000595 reg_loss: 0.000000
# Iteration: 288  reg_dec: 0.000144 loss: 0.116917 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 289  reg_dec: 0.000147 loss: 0.122947 reg_enc: 0.000601 reg_loss: 0.000000
# Iteration: 290  reg_dec: 0.000146 loss: 0.122753 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 291  reg_dec: 0.000142 loss: 0.121165 reg_enc: 0.000590 reg_loss: 0.000061
# Iteration: 292  reg_dec: 0.000141 loss: 0.131092 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 293  reg_dec: 0.000144 loss: 0.112509 reg_enc: 0.000590 reg_loss: 0.000000
# Iteration: 294  reg_dec: 0.000143 loss: 0.136403 reg_enc: 0.000594 reg_loss: 0.000000
# Iteration: 295  reg_dec: 0.000146 loss: 0.120552 reg_enc: 0.000592 reg_loss: 0.000000
# Iteration: 296  reg_dec: 0.000141 loss: 0.127924 reg_enc: 0.000599 reg_loss: 0.000000
# Iteration: 297  reg_dec: 0.000143 loss: 0.121787 reg_enc: 0.000598 reg_loss: 0.000000
# Iteration: 298  reg_dec: 0.000139 loss: 0.125009 reg_enc: 0.000604 reg_loss: 0.000000
# Iteration: 299  reg_dec: 0.000143 loss: 0.131715 reg_enc: 0.000596 reg_loss: 0.000000
# Iteration: 300  reg_dec: 0.000144 loss: 0.114672 reg_enc: 0.000595 reg_loss: 0.000000
# 'model_params/new_10000_0.0005_301_0.75_300_-2.0_2.0_2.5_1.0_adam.ckpt'

# %%
eval_ops = {
    'tp': tp,
    't': t,
    's': s,
    'sp': sp,
    'y_encoder': y_encoder,
    'y_decoder': y_decoder,
    'mse': rec_loss
}

vals = _eval_graph(
    graph=g,
    saver=saver,
    eval_ops=eval_ops,
    data_object=data_gen_val,
    feed_vars=feed_vars,
    param_file='model_params/' + param_string + '.ckpt-300') #added -150 to get latest checkpoint
# Out:
# INFO:tensorflow:Restoring parameters from model_params/new_10000_0.0005_301_0.75_300_-2.0_2.0_2.5_1.0_adam.ckpt-300

# %%
10 * np.log10(1/vals['mse'])
# Out:
# 9.4166670436433293

# %%
plot_string = param_string +'.png'
plot_string_svg = param_string + '.svg'
plot_string_eps = param_string + '.eps'

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
titles = ['X','V','R',r'$\hat{X}$']
xs_v = linspace(orig_vmin,orig_vmax, 1e3)
xs_r = linspace(orig_rmin,orig_rmax, 1e3)
i = 0
for ax, k in zip(axes.flat, ['tp', 't', 's', 'sp']):
    weights = np.ones_like(vals[k])/float(len(vals[k]))
    n_hist, bins_hist, _ = ax.hist(vals[k], bins=30,weights=weights,color='blue')
    ax.set_xlabel(titles[i])
    if k == 'tp':
        ax.set_xlim(-4,4)
    if k == 't':
        ax.set_xticks(np.linspace(-2,2,5))
        ax.set_xticklabels(np.linspace(orig_vmin,orig_vmax,5))
        
        hist_vals = dict(n = n_hist, bins = bins_hist )
        savez('resulting'+'_'+k+'_'+"hist.npz", data=hist_vals)
    if k == 's':
        ax.set_xticks(np.linspace(-2,2,5))
        ax.set_xticklabels(np.round(np.linspace(4.5,5.7,5),2))
    i+=1
#     ax.set_yscale('log')
    
_= axes[1,1].set_xlim(*(axes[0, 0].get_xlim()))
if pcm_device == 'new':
    base_name = 'Plots/data_hists_new_'
else: 
    base_name = 'Plots/data_hists_old_'

plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)
# Out:
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   app.launch_new_instance()
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
plt.plot(vs_data, mus_data)
plt.scatter(vals['t'], vals['s'])
if pcm_device == 'new':
    base_name = 'Plots/data_scatter_new_'
else: 
    base_name = 'Plots/data_scatter_old_'
plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)

# %%
_ = plt.hist2d(vals['t'].ravel(), vals['s'].ravel(), bins=50, norm=LogNorm())

# %%
f = interpolate.InterpolatedUnivariateSpline(xx, vals['y_encoder'], k=3)
g = interpolate.InterpolatedUnivariateSpline(vs_data, mus_data, k=3)
h = interpolate.InterpolatedUnivariateSpline(xx, vals['y_decoder'], k=3)

# %%
xs = linspace(xx[0][0],xx[-1][0], 1e3)
xs_v = linspace(orig_vmin,orig_vmax, 1e3)
xs_r = linspace(orig_rmin,orig_rmax, 1e3)
# Out:
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   if __name__ == '__main__':
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   from ipykernel import kernelapp as app
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   app.launch_new_instance()

# %%
plt.figure(figsize=(25,15))
plt.plot(xs, f(xs), 'r', lw=2, alpha=0.7, label='encoder')
plt.plot(xs, g(xs), c='orange', lw=2, alpha=0.7, label='pcm')
plt.plot(xs, h(xs), c='green', lw=2, alpha=0.7, label='decoder')
plt.plot(xs, h(g(f(xs))), c='blue', lw=2, alpha=0.7, label='xhat')
plt.plot(xx, xx, 'k--', label='x')
# plt.xlim(-3.0,3.0)
# plt.ylim(-3.0,3.0)
plt.title('SNR = '+str(round(10 * np.log10(1/vals['mse']),2)), fontsize=20)
legend(loc=(1.01,0.8), fontsize=20)

if pcm_device == 'new':
    base_name = 'Plots/enc_dec_plot_new_'
else: 
    base_name = 'Plots/enc_dec_plot_old_'
plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)

# %%
xs_new = np.linspace(-2,2, 1e3)
# Out:
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   if __name__ == '__main__':

# %%
from get_data import normalizer

xs_new = np.linspace(-2,2, 1e3)
figure_thang, (ax1) = plt.subplots(1, figsize=(10,10))
ax1.plot(xs_new, normalizer(f(xs_new),orig_vmin,orig_vmax), 'r', lw=2, alpha=0.7, label='encoder')
ax1.set_aspect('auto')
ax1.set_xlabel(r'$s$', fontsize=30)
ax1.set_ylabel(r'$V_{WL}\left(V\right)$', fontsize=30)

ax1.set_title('SNR = '+str(round(10 * np.log10(1/vals['mse']),2)), fontsize=20)
legend(loc=(1.01,0.8), fontsize=20)


if pcm_device == 'new':
    base_name = 'Plots/enc_plot_new_'
else: 
    base_name = 'Plots/enc_plot_old_'
plt.savefig(base_name+plot_string)

figure_thang, (ax2) = plt.subplots(1, figsize=(10,10))
ax2.plot(xs_r, h(xs_new), c='green', lw=2, alpha=0.7, label='decoder')
ax2.set_title('SNR = '+str(round(10 * np.log10(1/vals['mse']),2)), fontsize=20)
ax2.set_aspect('auto')
ax2.set_ylim(-2.5,2.5)
ax2.set_ylabel(r'$\hat{s}$', fontsize=30)
ax2.set_xlabel(r'$\log\left(R\right)$', fontsize=30)
legend(loc=(1.01,0.8), fontsize=20)

if pcm_device == 'new':
    base_name = 'Plots/dec_plot_new_'
else: 
    base_name = 'Plots/dec_plot_old_'
plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)
# Out:
# /Users/zarcone/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   app.launch_new_instance()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
hist_plot = ax.hist2d(vals['tp'].ravel(), vals['sp'].ravel(), 
              bins=50,cmap='jet', 
              range=np.array([(-2.0, 2.0), (-2.0, 2.0)]), normed='True')
ax.plot(xx,xx)
ax.set_aspect('equal')
plt.colorbar(hist_plot[3],ax=ax)
ax.set_xlabel(r'$s$', fontsize=20)
ax.set_ylabel(r'$\hat{s}$', fontsize=20)

if pcm_device == 'new':
    base_name = 'Plots/x_xhat_hist_new_'
else: 
    base_name = 'Plots/x_xhat_hist_old_'
plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)

# %%
figure_thang, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(30,10), gridspec_kw = {'width_ratios':[1, 1, 1.4]})

ax1.plot(xs_new, normalizer(f(xs_new),orig_vmin,orig_vmax), 'r', lw=6, alpha=0.7)
ax1.set_aspect('auto')
ax1.set_xlabel(r'$s$', fontsize=30)
ax1.set_ylabel(r'$V_{WL}\left(V\right)$', fontsize=30, rotation=0)
ax1.yaxis.set_label_coords(-0.225, 0.475)
ax1.xaxis.set_ticks(np.linspace(-2,2,5))
ax1.tick_params(axis="both", labelsize=20)
ax1.set_title("Encoder (F)", fontsize=20)
ax1.title.set_position((0.5,1.02))

ax2.plot(xs_r, h(xs_new), c='green', lw=6, alpha=0.7)
ax2.set_aspect('auto')
ax2.set_ylim(-2.25,2.25)
ax2.set_ylabel(r'$\hat{s}$', fontsize=30, rotation=0)
ax2.set_xlabel(r'$\log\left(R\right)$', fontsize=30)
ax2.yaxis.set_label_coords(-0.1, 0.475)
ax2.tick_params(axis="both", labelsize=20)
ax2.yaxis.set_ticks(np.linspace(-2,2,5))
ax2.set_title("Decoder (G)", fontsize=20)
ax2.title.set_position((0.5,1.02))


hist_plot = ax3.hist2d(vals['tp'].ravel(), vals['sp'].ravel(), 
              bins=40,cmap='jet', 
              range=np.array([(-2.0, 2.0), (-2.0, 2.0)]), normed='True')
ax3.plot(xx,xx, c='pink', lw=2)
ax3.set_aspect('equal')
plt.colorbar(hist_plot[3],ax=ax3)
ax3.set_xlabel(r'$s$', fontsize=30)
ax3.set_ylabel(r'$\hat{s}$', fontsize=30, rotation=0)
ax3.yaxis.set_label_coords(-0.1, 0.475)
ax3.tick_params(axis="both", labelsize=20)
ax3.yaxis.set_ticks(np.linspace(-2,2,5))
ax3.xaxis.set_ticks(np.linspace(-2,2,5))




ax3.set_title('SNR = '+str(round(10 * np.log10(1/vals['mse']),2)) +' dB', fontsize=20)
ax3.title.set_position((0.5,1.02))

if pcm_device == 'new':
    base_name = 'Plots/combined_enc_dec_hist'
else: 
    base_name = 'Plots/combined_enc_dec_hist'

plt.savefig(base_name+plot_string, transparent=True)
plt.savefig(base_name+plot_string_svg, transparent=True)
plt.savefig(base_name+plot_string_eps, transparent=True)
